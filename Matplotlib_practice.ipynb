# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 79.7 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 75.9 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 76.3 MB/s  0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-11.3.0 pyparsing-3.2.5

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


# x = np.linspace(0, 2 * np.pi, 200)
# y = np.sin(x)
# fig, ax = plt.subplots(figsize=(7,4))
# ax.set_title('Sin Wave')
# ax.plot(x,y)
# plt.show()

# xpoints = np.array([0,5])
# ypoints = np.array([0,200])
# plt.plot(xpoints,ypoints)
# plt.show()

# x2 = np.array([1989, 1992, 1990, 1995, 2000, 2025, 2022, 2018, 2019, 2023])
# y2 = np.array([240,250,260,270,280,290,300,310,320,330])
# plt.plot(x,y)
# plt.xlabel('Year')
# plt.ylabel('Price')
# plt.show()

#REGULAR GRAPH
# x = np.array([90,75,80,55,104,103,99,88,78,94])
# y = np.array([140,550,450,880,480,270,490,300,430,360])
# plt.title('Sports Data')
# plt.xlabel('Average Pulse')
# plt.ylabel('Calorie Burnt')
# plt.plot(x,y)
# plt.grid()
# plt.show()

#SCATTER PLOT
# x = np.array([90,75,80,55,104,103,99,88,78,94])
# y = np.array([140,550,450,880,480,270,490,300,430,360])
# plt.scatter(x,y)
# plt.show()

#BAR CHART
# x = np.array(['A','B','C','D'])
# y = np.array([5,7,3,11])
# plt.bar(x,y)
# plt.show()

#HISTOGRAM
# data = np.random.randn(1000)
# plt.hist(data, bins=30, density=True, color = 'red', edgecolor='black',alpha=0.7)
# plt.xlabel('Values')
# plt.ylabel('Probability Density')
# plt.title('Histogram')
# plt.show()
# x = np.random.normal(170,10,250)
# plt.hist(x)
# plt.show()

#PIE CHART
# y = np.array([35,25,25,15])
# plt.pie(y)
# plt.show()

#3D SCATTER PLOT
# x = np.random.rand(50)
# y = np.random.rand(50)
# z = np.random.rand(50)
# fig = plt.figure()
# ax = fig.add_subplot(111,projection='3d')
# ax.scatter(x,y,z, c='blue', marker='o', label='Data Points')
# ax.set_xlabel('X Axis')
# ax.set_ylabel('Y Axis')
# ax.set_zlabel('Z Axis')
# ax.set_title('Basic 3D Scatter Plot')

#3D BAR GRAPH
# vehicle_type = ['Car']
# sales_region = ['North','South']
# sales_volume = [[150,120]]
# fig = plt.figure()
# ax = fig.add_subplot(111,projection='3d')
# for i in range(len(vehicle_type)):
#     for j in range(len(sales_region)):
#         ax.bar3d(i,j,0,0.8,0.8,sales_volume[i][j])
# ax.set_xlabel('Vehicle Type')
# ax.set_ylabel('Sales Region')
# ax.set_zlabel('Sales Volume')
# ax.set_title('Basic 3D Bar Graph')
# plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\arnuv\anaconda3\envs\my-environment\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0,1,2,3,4,5])
plt.show()
